# %% [markdown]
# <a href="https://colab.research.google.com/github/Luismrr/Primer_Challenge/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
total_ventas_MM={}
total_ventas_MM['tienda_1']=tienda['Precio'].sum()/(1000000)
total_ventas_MM['tienda_2']=tienda2['Precio'].sum()/(1000000)
total_ventas_MM['tienda_3']=tienda3['Precio'].sum()/(1000000)
total_ventas_MM['tienda_4']=tienda4['Precio'].sum()/(1000000)

print(total_ventas_MM)

for tienda, total_venta in total_ventas_MM.items():
  print(f'{tienda}: {total_venta:.2f}')
# Out:
# {'tienda_1': np.float64(1150.8804), 'tienda_2': np.float64(1116.3435), 'tienda_3': np.float64(1098.0196), 'tienda_4': np.float64(1038.3757)}
# tienda_1: 1150.88
# tienda_2: 1116.34
# tienda_3: 1098.02
# tienda_4: 1038.38

# %% [markdown]
# La tienda que me genera menos ventas son Tienda 4,  Tienda 3, Tienda 2, Tienda 1
#
#
# 1.   Tienda 4
# 2.   Tienda 3
# 3.   Tienda 2
# 4.   Tienda 1

# %%
tienda.columns
# Out:
# Index(['Producto', 'Categoría del Producto', 'Precio', 'Costo de envío',
#        'Fecha de Compra', 'Vendedor', 'Lugar de Compra', 'Calificación',
#        'Método de pago', 'Cantidad de cuotas', 'lat', 'lon'],
#       dtype='object')

# %% [markdown]
# # 2. Ventas por categoría

# %%
tienda.groupby('Categoría del Producto').size().sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# dtype: int64

# %%
tienda2.groupby('Categoría del Producto').size().sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# dtype: int64

# %%
tienda3.groupby('Categoría del Producto').size().sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Artículos para el hogar    177
# Instrumentos musicales     177
# dtype: int64

# %%
tienda4.groupby('Categoría del Producto').size().sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# dtype: int64

# %% [markdown]
# Todas las tiendas tienen entre sus principales productos
#
# 1.   Muebles
# 2.   Electrónicos
# 3.   Juguetes
#
# Asi que la venta de una de ellas no representará un impacto sustancial hacia los clientes.

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
tienda['Calificación'].mean()

Calificacion_promedio={}
Calificacion_promedio['tienda_1']=tienda['Calificación'].mean()
Calificacion_promedio['tienda_2']=tienda2['Calificación'].mean()
Calificacion_promedio['tienda_3']=tienda3['Calificación'].mean()
Calificacion_promedio['tienda_4']=tienda4['Calificación'].mean()

# %%
for tienda, cal in Calificacion_promedio.items():
  print(f'{tienda}: {cal:.2f} puntos' )
# Out:
# tienda_1: 3.98 puntos
# tienda_2: 4.04 puntos
# tienda_3: 4.05 puntos
# tienda_4: 4.00 puntos

# %% [markdown]
# La tiendas ordenadas con Menor Valoracion son:
#
#
# 1.   Tienda 1
# 2.   Tienda 4
# 3.   Tienda 2
# 4.   Tienda 3

# %%
import matplotlib.pyplot as plt

# %%
Tiendas = list(total_ventas_MM.keys())
Total_ventas = list(total_ventas_MM.values())
Calificaciones = list(Calificacion_promedio.values())

figura_ventas_cal, eje1 = plt.subplots(figsize=(6,4))

# Eje1 ventas
color1 = 'tab:blue'
eje1.set_xlabel('Tiendas')
eje1.set_ylabel('Total ventas (MM)',color=color1)
eje1.bar(Tiendas,Total_ventas, color=color1, alpha = 0.6, width=0.4)
eje1.tick_params(axis='y', labelcolor=color1)

# Eje2 calificaciones
eje2 = eje1.twinx()  #dobe eje
color2='tab:red'
eje2.set_ylabel('Calificación Promedio',color=color2)
eje2.plot(Tiendas,Calificaciones, color=color2, marker='o')
eje2.tick_params(axis='y', labelcolor=color2)

plt.title('Total Ventas (MM) vs Calificacion promedio por tienfa')
figura.tight_layout()
eje1.grid(axis='y', linestyle='--', alpha=0.5)
figura.tight_layout(pad=2)
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
Tops_prod_tienda1=tienda.groupby('Producto').size().sort_values(ascending = False)
Tops_prod_tienda2=tienda2.groupby('Producto').size().sort_values(ascending = False)
Tops_prod_tienda3=tienda3.groupby('Producto').size().sort_values(ascending = False)
Tops_prod_tienda4=tienda4.groupby('Producto').size().sort_values(ascending = False)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# PRODUCTOS MAS VENDIDOS

# %%
top_10_tienda1 = Tops_prod_tienda1.head(10).plot(kind='bar',figsize=(8,5),title='Top Productos mas vendidos Tienda 1')
plt.xlabel('Producto')
plt.ylabel('Cantidad vendida')
plt.tight_layout()
plt.show()

top_10_tienda2 = Tops_prod_tienda2.head(10).plot(kind='bar',figsize=(8,5),title='Top Productos mas vendidos Tienda 2')
plt.xlabel('Producto')
plt.ylabel('Cantidad vendida')
plt.tight_layout()
plt.show()

top_10_tienda3 = Tops_prod_tienda3.head(10).plot(kind='bar',figsize=(8,5),title='Top Productos mas vendidos Tienda 3')
plt.xlabel('Producto')
plt.ylabel('Cantidad vendida')
plt.tight_layout()
plt.show()

top_10_tienda4 = Tops_prod_tienda4.head(10).plot(kind='bar',figsize=(8,5),title='Top Productos mas vendidos Tienda 4')
plt.xlabel('Producto')
plt.ylabel('Cantidad vendida')
plt.tight_layout()
plt.show()

# %% [markdown]
# PRODUCTOS MENOS VENDIDOS

# %%
bottom_10_tienda1 = Tops_prod_tienda1.tail(10).plot(kind='bar',figsize=(8,5),title='Productos Menos vendidos Tienda 1')
plt.xlabel('Producto')
plt.ylabel('Cantidad vendida')
plt.tight_layout()
plt.show()

bottom_10_tienda2 = Tops_prod_tienda2.tail(10).plot(kind='bar',figsize=(8,5),title='Productos Menos vendidos Tienda 2')
plt.xlabel('Producto')
plt.ylabel('Cantidad vendida')
plt.tight_layout()
plt.show()

bottom_10_tienda3 = Tops_prod_tienda3.tail(10).plot(kind='bar',figsize=(8,5),title='Productos Menos vendidos Tienda 3')
plt.xlabel('Producto')
plt.ylabel('Cantidad vendida')
plt.tight_layout()
plt.show()

bottom_10_tienda4 = Tops_prod_tienda4.tail(10).plot(kind='bar',figsize=(8,5),title='Productos Menos vendidos Tienda 4')
plt.xlabel('Producto')
plt.ylabel('Cantidad vendida')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
costo_envio_tienda = {}
costo_envio_tienda['tienda_1']=tienda['Costo de envío'].mean()
costo_envio_tienda['tienda_2']=tienda2['Costo de envío'].mean()
costo_envio_tienda['tienda_3']=tienda3['Costo de envío'].mean()
costo_envio_tienda['tienda_4']=tienda4['Costo de envío'].mean()

for tienda, costo in costo_envio_tienda.items():
    print(f"{tienda}: {costo:.2f}")
# Out:
# tienda_1: 26018.61
# tienda_2: 25216.24
# tienda_3: 24805.68
# tienda_4: 23459.46

# %% [markdown]
# Se gasta mas en el envio de las Tiendas 1   y   Tienda 2
#
# 1.   Tienda 1
# 2.   Tienda 2
# 3.   Tienda 3
# 4.   Tienda 4

# %%
costo_envio_tienda
Tiendas = list(total_ventas_MM.keys())
Costo_envio = list(costo_envio_tienda.values())
Calificaciones = list(Calificacion_promedio.values())

figura_cost_envio_Calif, eje1 = plt.subplots(figsize=(6,5))

# Eje1 ventas
color1 = 'tab:blue'
eje1.set_xlabel('Tiendas')
eje1.set_ylabel('Costo Envio Avg',color=color1)
eje1.bar(Tiendas,Costo_envio, color=color1, alpha = 0.6, width=0.5)
eje1.tick_params(axis='y', labelcolor=color1)

# Eje2 calificaciones
eje2 = eje1.twinx()  #dobe eje
color2='tab:red'
eje2.set_ylabel('Calificación Avg',color=color2)
eje2.plot(Tiendas,Calificaciones, color=color2, marker='o')
eje2.tick_params(axis='y', labelcolor=color2)

plt.title('Costo Envio vs Calificacion promedio por tienda')
figura.tight_layout()
eje1.grid(axis='y', linestyle='--', alpha=0.5)
figura.tight_layout(pad=3)
plt.show()

# %% [markdown]
# # INFORME FINAL

# %% [markdown]
# **INTRODUCCIÓN**:
#
# Se realizó el análisis de los datos de ventas de las 4 tiendas que posee el Sr. Juan con el objetivo de determinar aquella tienda que presente menor rendimiento en general tomando en cuenta 5 factores principales como son:
#
# *   Ingresos totales
# *   Categorias de productos mas y menos vendidas
# *   Calificaciones de los clientes
# *   Los productos mas y menos vendidos
# *   Coste de envío promedio
#
# De tal modo que luego de la venta de la tienda le permita poder hacer una inversión en otro rubro de mayor beneficio económico.

# %% [markdown]
# **DESARROLLO:**

# %% [markdown]
# Del análisis de los 5 factores analizados se observa:
#
# 1.   La venta de las 4 tiendas obtienen sus mayores ingresos de la venta de productos en las categorias:
#
# *   Muebles
# *   Productos Electrónicos
# *   Juguetes
#
#
#
# 2.  Hay 2 factores que son muy determinantes al momento de elegir que tienda tiene el menor desempeño ya que tienen valores muy diferenciados. Estos factores son:
#
# *   Ingresos totales
# *   Calificaciones de los clientes

# %%
figura_ventas_cal

# %% [markdown]
# De la grafica **figura_ventas_cal** se observa:
#
# *   La **tienda 4** obtiene el **Menor ingreso de ventas** con un valor de 1,038 Millones de Soles.
# *   La tienda 1 tiene la peor calificación de los clientes. Sin embargo NO debe ser candidato a venta ya que es la que mayor ingreso por venta obtiene: 1,150 Millones de Soles
# *   La **tienda 4** en la **segunda peor en cuanto a calificación** de clientes.
# *   Tambien se observa que la tienda 3 es la mejor en cuanto a calificación de cliente se refiere.

# %% [markdown]
# Por otra parte si analizamos el costo de envio por tienda vemos algo particular.

# %%
figura_cost_envio_Calif

# %% [markdown]
# *   La tienda 4 es la que menor costo de envío tiene.
# *   Al relacionarlo con la calificación, a pesar de tener menor costo de envió la calificación de los cliente es baja respecto de las tiendas 2 y 3.

# %% [markdown]
# **CONCLUSIÓN**
#
# Se concluye que considerando los factores de desempeño de ventas, la baja calificación de ventas y el costo de envio, la tienda que debe vender el Sr. Juan debido a su bajo desempeño debe ser la **Tienda 4**.
#
# Ademas se recomienda que las otras tiendas incrementen el stock los productos mas vendidos de la Tienda 4 que principalmente son:
#
# *   Camas Box
# *   Camas King
# *   Cuberteria

# %% [markdown]
# >
